# %% [markdown]
# 如果跑run_CartPole.py要自己切换interpreter,因为默认的interpreter是global env中的那个python interpreter。在terminal中activate spinningup貌似并不能改变vs code的interpreter。vscode下面的bar也可以看到lang mode和解释器
#
# https://code.visualstudio.com/docs/python/environments
#
# Command+Shift+P, Python:select Interpreter
#
# ![image.png](attachment:image.png)

# %% [markdown]
# 不知道怎么在vscode中查cartpole的env source code
#
# /opt/homebrew/Caskroom/miniforge/base/envs/spinningup/lib/python3.9/site-packages/gym/envs/classic_control

# %% [markdown]
# RL_brain和延用了DQN的network，可以在DQN中看注释
#
#
# cartpole观察现象：
#
# 一开始死的快，步数少，直到几十个episode(total steps>1000)才开始learn并且increment epsilon，后续每一步都会learn一次，而每learn一次都会increment 0.01，所以epsilon其实很快就达到max
