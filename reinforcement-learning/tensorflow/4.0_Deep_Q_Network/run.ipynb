# %%
#conda list

# %% [markdown]
# 原代码是morvan tf1写的，有些地方改了改跑通的。其实目前使用tf keras或者pytorch搭nn更方便的，不用整那么多placeholder

# %% [markdown]
# #Some hyperparameters:
# epoches：games轮数（300）
# alpha (LearningRate):0.01
#
# Gamme(reward_decay)=0.9,
# Epsilon(e_greedy)=0.9,
# epsilon的increment并未设置.
# replace_target_iter=200, 即每学200次解冻target net参数，同步为最新参数
# memory_size=2000,
#
#
# step记录程序开始后的总步数，200步后每5步 learn一次
#
# #确认输出顺序无误
#
# 输出是没问题的，在text editor里看完整的就好
#
# #解释图
#
# RL并不是一开始就拥有所有数据，所以它的GD训练的cost不是一直下降的，由于新经历等的加入，可能训练一段时间后还会上升cost，所以看到的plot是很典型的RL. 可以取很大的epoches试试看
#
# #问题复杂性减弱
# 如果有两(多)个坑，记忆库中掉坑的记忆多，学习获胜的记忆太少，效果不好
# possible solutions:
# 1.多个坑，扩大记忆库并且限定当获胜记忆高于几次比如5次后再开始learn
# 2.初期给负面记忆/正面记忆的ratio设定一个bar，learn一段时间后去掉bar
#
# #save_load
#
# TBD
#
# #查看logs
# activate spinningup env
# tensorboard --logdir=logs
# 可以对照代码注释再过一遍图的结构和input，output，node的dimensions
#
# E.g. eval_net
# input[?*2] ✖️ Assign[2*10] ✖️ Assign_2[10*4] = loss[?*4]
# 可以看出，assign即l1的w，assign_2为l2的w, assign_1和assign_3分别为b1、b2
# 不同懂subgraph node个数什么意思以及loss给train的2tensors是什么
#
#
# #extend to a more complex scenario E.g. Atari Game: Space Invaders
#
# TBD

# %%
from maze_env import Maze
from RL_brain import DeepQNetwork      

epoches=1500
def run_maze():
    step = 0 #记录当前总步数，用来决定target_net的定期更新
    for episode in range(epoches):
        # initial observation
        observation = env.reset()

        while True:
            # fresh env
            env.render()

            # RL choose action based on observation
            action = RL.choose_action(observation)

            # RL take action and get next observation and reward
            observation_, reward, done = env.step(action)

            RL.store_transition(observation, action, reward, observation_)

            #200步以后 每5步learn一次，注意这个step是从运行开始算，不是每个episode的step。
            # 这个有什么很特别的意义吗？
            # Re：1.感觉主要也是先积累一些记忆再开始训练，不然一方面样本少，都不够minibatch size，
            #     2.另一方面开始太早的话sample和没sample一样，sequentail 特征太强，我们需要的是减少一些相关性
            if (step > 200) and (step % 5 == 0):
                RL.learn()

            # swap observation
            observation = observation_

            #update step
            step += 1

            # break while loop when end of this episode
            if done:
                print('Episode '+str(episode)+', total steps= '+str(step))
                break
            

    # end of game
    print('game over')
    env.destroy()


if __name__ == "__main__":
    # maze game
    env = Maze()
    RL = DeepQNetwork(env.n_actions, env.n_features,
                      learning_rate=0.01,   
                      reward_decay=0.9,
                      e_greedy=0.9,
                      replace_target_iter=200,    #像这种defintion function中已有预设的参数，此时会覆盖掉吧
                      memory_size=2000,
                      output_graph=True          
                      )
    print(RL.replace_target_iter)
    env.after(epoches, run_maze)
    env.mainloop()
    RL.plot_cost()
# Out:
# WARNING:tensorflow:From /opt/homebrew/Caskroom/miniforge/base/envs/spinningup/lib/python3.9/site-packages/tensorflow/python/compat/v2_compat.py:107: disable_resource_variables (from tensorflow.python.ops.variable_scope) is deprecated and will be removed in a future version.
# Instructions for updating:
# non-resource variables are not supported in the long term
# WARNING:tensorflow:From /opt/homebrew/Caskroom/miniforge/base/envs/spinningup/lib/python3.9/site-packages/tensorflow/python/training/rmsprop.py:188: calling Ones.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# 200
# 2023-08-02 18:02:40.627917: W tensorflow/tsl/platform/profile_utils/cpu_utils.cc:128] Failed to get CPU frequency: 0 Hz
# Episode 0, total steps= 125
# Episode 1, total steps= 196
#
# learn steps=0: target_params_replaced
#
# learn steps til now= 1
# learn steps til now= 2
# learn steps til now= 3
# learn steps til now= 4
# learn steps til now= 5
# learn steps til now= 6
# learn steps til now= 7
# learn steps til now= 8
# learn steps til now= 9
# learn steps til now= 10
# learn steps til now= 11
# learn steps til now= 12
# learn steps til now= 13
# learn steps til now= 14
# learn steps til now= 15
# learn steps til now= 16
# learn steps til now= 17
# learn steps til now= 18
# learn steps til now= 19
# learn steps til now= 20
# learn steps til now= 21
# learn steps til now= 22
# learn steps til now= 23
# learn steps til now= 24
# learn steps til now= 25
# learn steps til now= 26
# learn steps til now= 27
# learn steps til now= 28
# learn steps til now= 29
# learn steps til now= 30
# learn steps til now= 31
# learn steps til now= 32
# learn steps til now= 33
# learn steps til now= 34
# learn steps til now= 35
# learn steps til now= 36
# learn steps til now= 37
# learn steps til now= 38
# learn steps til now= 39
# learn steps til now= 40
# learn steps til now= 41
# learn steps til now= 42
# learn steps til now= 43
# learn steps til now= 44
# learn steps til now= 45
# learn steps til now= 46
# learn steps til now= 47
# learn steps til now= 48
# learn steps til now= 49
# learn steps til now= 50
# learn steps til now= 51
# Episode 2, total steps= 456
# learn steps til now= 52
# learn steps til now= 53
# learn steps til now= 54
# learn steps til now= 55
# learn steps til now= 56
# learn steps til now= 57
# learn steps til now= 58
# learn steps til now= 59
# Episode 3, total steps= 500
# learn steps til now= 60
# learn steps til now= 61
# learn steps til now= 62
# learn steps til now= 63
# learn steps til now= 64
# learn steps til now= 65
# learn steps til now= 66
# learn steps til now= 67
# learn steps til now= 68
# learn steps til now= 69
# learn steps til now= 70
# learn steps til now= 71
# learn steps til now= 72
# learn steps til now= 73
# learn steps til now= 74
# learn steps til now= 75
# learn steps til now= 76
# learn steps til now= 77
# learn steps til now= 78
# learn steps til now= 79
# learn steps til now= 80
# learn steps til now= 81
# learn steps til now= 82
# learn steps til now= 83
# learn steps til now= 84
# learn steps til now= 85
# learn steps til now= 86
# learn steps til now= 87
# learn steps til now= 88
# learn steps til now= 89
# learn steps til now= 90
# learn steps til now= 91
# learn steps til now= 92
# Episode 4, total steps= 665
# learn steps til now= 93
# learn steps til now= 94
# learn steps til now= 95
# learn steps til now= 96
# learn steps til now= 97
# learn steps til now= 98
# learn steps til now= 99
# learn steps til now= 100
# learn steps til now= 101
# learn steps til now= 102
# learn steps til now= 103
# learn steps til now= 104
# learn steps til now= 105
# learn steps til now= 106
# learn steps til now= 107
# learn steps til now= 108
# learn steps til now= 109
# learn steps til now= 110
# learn steps til now= 111
# Episode 5, total steps= 756
# learn steps til now= 112
# learn steps til now= 113
# learn steps til now= 114
# learn steps til now= 115
# learn steps til now= 116
# learn steps til now= 117
# learn steps til now= 118
# learn steps til now= 119
# learn steps til now= 120
# learn steps til now= 121
# learn steps til now= 122
# learn steps til now= 123
# learn steps til now= 124
# learn steps til now= 125
# learn steps til now= 126
# learn steps til now= 127
# Episode 6, total steps= 837
# learn steps til now= 128
# learn steps til now= 129
# learn steps til now= 130
# learn steps til now= 131
# learn steps til now= 132
# learn steps til now= 133
# learn steps til now= 134
# learn steps til now= 135
# learn steps til now= 136
# learn steps til now= 137
# learn steps til now= 138
# learn steps til now= 139
# learn steps til now= 140
# learn steps til now= 141
# learn steps til now= 142
# learn steps til now= 143
# learn steps til now= 144
# learn steps til now= 145
# learn steps til now= 146
# learn steps til now= 147
# learn steps til now= 148
# learn steps til now= 149
# learn steps til now= 150
# learn steps til now= 151
# learn steps til now= 152
# learn steps til now= 153
# learn steps til now= 154
# learn steps til now= 155
# learn steps til now= 156
# learn steps til now= 157
# learn steps til now= 158
# learn steps til now= 159
# learn steps til now= 160
# learn steps til now= 161
# learn steps til now= 162
# learn steps til now= 163
# learn steps til now= 164
# learn steps til now= 165
# learn steps til now= 166
# learn steps til now= 167
# learn steps til now= 168
# learn steps til now= 169
# learn steps til now= 170
# learn steps til now= 171
# Episode 7, total steps= 1058
# learn steps til now= 172
# learn steps til now= 173
# learn steps til now= 174
# learn steps til now= 175
# learn steps til now= 176
# learn steps til now= 177
# learn steps til now= 178
# learn steps til now= 179
# Episode 8, total steps= 1098
# learn steps til now= 180
# learn steps til now= 181
# learn steps til now= 182
# learn steps til now= 183
# learn steps til now= 184
# learn steps til now= 185
# Episode 9, total steps= 1127
# learn steps til now= 186
# learn steps til now= 187
# learn steps til now= 188
# learn steps til now= 189
# learn steps til now= 190
# learn steps til now= 191
# learn steps til now= 192
# learn steps til now= 193
# Episode 10, total steps= 1170
# learn steps til now= 194
# learn steps til now= 195
# learn steps til now= 196
# learn steps til now= 197
# learn steps til now= 198
# learn steps til now= 199
# learn steps til now= 200
# Episode 11, total steps= 1202
#
# learn steps=200: target_params_replaced
#
# learn steps til now= 201
# learn steps til now= 202
# learn steps til now= 203
# learn steps til now= 204
# learn steps til now= 205
# learn steps til now= 206
# learn steps til now= 207
# learn steps til now= 208
# Episode 12, total steps= 1244
# learn steps til now= 209
# learn steps til now= 210
# learn steps til now= 211
# learn steps til now= 212
# learn steps til now= 213
# learn steps til now= 214
# learn steps til now= 215
# learn steps til now= 216
# learn steps til now= 217
# Episode 13, total steps= 1290
# learn steps til now= 218
# learn steps til now= 219
# learn steps til now= 220
# learn steps til now= 221
# Episode 14, total steps= 1308
# learn steps til now= 222
# learn steps til now= 223
# learn steps til now= 224
# learn steps til now= 225
# learn steps til now= 226
# learn steps til now= 227
# learn steps til now= 228
# learn steps til now= 229
# learn steps til now= 230
# learn steps til now= 231
# learn steps til now= 232
# learn steps til now= 233
# Episode 15, total steps= 1368
# learn steps til now= 234
# learn steps til now= 235
# learn steps til now= 236
# learn steps til now= 237
# learn steps til now= 238
# learn steps til now= 239
# learn steps til now= 240
# learn steps til now= 241
# learn steps til now= 242
# learn steps til now= 243
# learn steps til now= 244
# learn steps til now= 245
# learn steps til now= 246
# learn steps til now= 247
# learn steps til now= 248
# learn steps til now= 249
# learn steps til now= 250
# learn steps til now= 251
# learn steps til now= 252
# Episode 16, total steps= 1461
# learn steps til now= 253
# learn steps til now= 254
# learn steps til now= 255
# learn steps til now= 256
# learn steps til now= 257
# learn steps til now= 258
# learn steps til now= 259
# learn steps til now= 260
# learn steps til now= 261
# learn steps til now= 262
# learn steps til now= 263
# learn steps til now= 264
# learn steps til now= 265
# learn steps til now= 266
# learn steps til now= 267
# learn steps til now= 268
# learn steps til now= 269
# learn steps til now= 270
# learn steps til now= 271
# learn steps til now= 272
# learn steps til now= 273
# learn steps til now= 274
# learn steps til now= 275
# learn steps til now= 276
# learn steps til now= 277
# learn steps til now= 278
# learn steps til now= 279
# learn steps til now= 280
# learn steps til now= 281
# learn steps til now= 282
# learn steps til now= 283
# learn steps til now= 284
# learn steps til now= 285
# learn steps til now= 286
# learn steps til now= 287
# learn steps til now= 288
# learn steps til now= 289
# learn steps til now= 290
# learn steps til now= 291
# Episode 17, total steps= 1658
# learn steps til now= 292
# learn steps til now= 293
# learn steps til now= 294
# learn steps til now= 295
# learn steps til now= 296
# learn steps til now= 297
# learn steps til now= 298
# learn steps til now= 299
# learn steps til now= 300
# learn steps til now= 301
# learn steps til now= 302
# learn steps til now= 303
# learn steps til now= 304
# learn steps til now= 305
# learn steps til now= 306
# learn steps til now= 307
# learn steps til now= 308
# learn steps til now= 309
# learn steps til now= 310
# learn steps til now= 311
# learn steps til now= 312
# learn steps til now= 313
# learn steps til now= 314
# learn steps til now= 315
# learn steps til now= 316
# learn steps til now= 317
# learn steps til now= 318
# learn steps til now= 319
# learn steps til now= 320
# learn steps til now= 321
# learn steps til now= 322
# learn steps til now= 323
# learn steps til now= 324
# learn steps til now= 325
# learn steps til now= 326
# learn steps til now= 327
# learn steps til now= 328
# learn steps til now= 329
# learn steps til now= 330
# learn steps til now= 331
# learn steps til now= 332
# learn steps til now= 333
# learn steps til now= 334
# learn steps til now= 335
# learn steps til now= 336
# learn steps til now= 337
# learn steps til now= 338
# learn steps til now= 339
# learn steps til now= 340
# learn steps til now= 341
# learn steps til now= 342
# learn steps til now= 343
# learn steps til now= 344
# learn steps til now= 345
# learn steps til now= 346
# learn steps til now= 347
# learn steps til now= 348
# learn steps til now= 349
# learn steps til now= 350
# learn steps til now= 351
# learn steps til now= 352
# learn steps til now= 353
# learn steps til now= 354
# learn steps til now= 355
# learn steps til now= 356
# learn steps til now= 357
# learn steps til now= 358
# learn steps til now= 359
# learn steps til now= 360
# learn steps til now= 361
# learn steps til now= 362
# learn steps til now= 363
# learn steps til now= 364
# learn steps til now= 365
# learn steps til now= 366
# learn steps til now= 367
# learn steps til now= 368
# learn steps til now= 369
# learn steps til now= 370
# learn steps til now= 371
# learn steps til now= 372
# learn steps til now= 373
# learn steps til now= 374
# learn steps til now= 375
# learn steps til now= 376
# learn steps til now= 377
# learn steps til now= 378
# learn steps til now= 379
# learn steps til now= 380
# learn steps til now= 381
# learn steps til now= 382
# learn steps til now= 383
# learn steps til now= 384
# learn steps til now= 385
# learn steps til now= 386
# Episode 18, total steps= 2131
# learn steps til now= 387
# learn steps til now= 388
# learn steps til now= 389
# learn steps til now= 390
# learn steps til now= 391
# learn steps til now= 392
# learn steps til now= 393
# learn steps til now= 394
# learn steps til now= 395
# learn steps til now= 396
# learn steps til now= 397
# learn steps til now= 398
# learn steps til now= 399
# learn steps til now= 400
#
# learn steps=400: target_params_replaced
#
# learn steps til now= 401
# learn steps til now= 402
# learn steps til now= 403
# learn steps til now= 404
# learn steps til now= 405
# learn steps til now= 406
# learn steps til now= 407
# learn steps til now= 408
# learn steps til now= 409
# learn steps til now= 410
# learn steps til now= 411
# learn steps til now= 412
# learn steps til now= 413
# learn steps til now= 414
# learn steps til now= 415
# learn steps til now= 416
# learn steps til now= 417
# learn steps til now= 418
# learn steps til now= 419
# learn steps til now= 420
# learn steps til now= 421
# learn steps til now= 422
# learn steps til now= 423
# learn steps til now= 424
# learn steps til now= 425
# learn steps til now= 426
# learn steps til now= 427
# learn steps til now= 428
# learn steps til now= 429
# learn steps til now= 430
# learn steps til now= 431
# learn steps til now= 432
# learn steps til now= 433
# learn steps til now= 434
# learn steps til now= 435
# learn steps til now= 436
# learn steps til now= 437
# learn steps til now= 438
# learn steps til now= 439
# learn steps til now= 440
# learn steps til now= 441
# learn steps til now= 442
# learn steps til now= 443
# learn steps til now= 444
# learn steps til now= 445
# learn steps til now= 446
# learn steps til now= 447
# learn steps til now= 448
# learn steps til now= 449
# learn steps til now= 450
# learn steps til now= 451
# learn steps til now= 452
# learn steps til now= 453
# learn steps til now= 454
# learn steps til now= 455
# learn steps til now= 456
# learn steps til now= 457
# learn steps til now= 458
# learn steps til now= 459
# learn steps til now= 460
# learn steps til now= 461
# Episode 19, total steps= 2506
# learn steps til now= 462
# learn steps til now= 463
# learn steps til now= 464
# learn steps til now= 465
# learn steps til now= 466
# learn steps til now= 467
# learn steps til now= 468
# learn steps til now= 469
# learn steps til now= 470
# learn steps til now= 471
# learn steps til now= 472
# learn steps til now= 473
# learn steps til now= 474
# learn steps til now= 475
# learn steps til now= 476
# learn steps til now= 477
# learn steps til now= 478
# learn steps til now= 479
# learn steps til now= 480
# learn steps til now= 481
# learn steps til now= 482
# learn steps til now= 483
# learn steps til now= 484
# learn steps til now= 485
# learn steps til now= 486
# learn steps til now= 487
# learn steps til now= 488
# learn steps til now= 489
# learn steps til now= 490
# learn steps til now= 491
# learn steps til now= 492
# learn steps til now= 493
# learn steps til now= 494
# learn steps til now= 495
# learn steps til now= 496
# learn steps til now= 497
# learn steps til now= 498
# Episode 20, total steps= 2693
# learn steps til now= 499
# learn steps til now= 500
# learn steps til now= 501
# learn steps til now= 502
# learn steps til now= 503
# learn steps til now= 504
# learn steps til now= 505
# learn steps til now= 506
# learn steps til now= 507
# learn steps til now= 508
# learn steps til now= 509
# learn steps til now= 510
# learn steps til now= 511
# learn steps til now= 512
# learn steps til now= 513
# learn steps til now= 514
# learn steps til now= 515
# learn steps til now= 516
# learn steps til now= 517
# learn steps til now= 518
# learn steps til now= 519
# learn steps til now= 520
# learn steps til now= 521
# learn steps til now= 522
# learn steps til now= 523
# learn steps til now= 524
# learn steps til now= 525
# learn steps til now= 526
# learn steps til now= 527
# learn steps til now= 528
# learn steps til now= 529
# learn steps til now= 530
# learn steps til now= 531
# learn steps til now= 532
# learn steps til now= 533
# learn steps til now= 534
# learn steps til now= 535
# learn steps til now= 536
# learn steps til now= 537
# learn steps til now= 538
# learn steps til now= 539
# learn steps til now= 540
# learn steps til now= 541
# learn steps til now= 542
# learn steps til now= 543
# learn steps til now= 544
# learn steps til now= 545
# learn steps til now= 546
# learn steps til now= 547
# learn steps til now= 548
# learn steps til now= 549
# learn steps til now= 550
# learn steps til now= 551
# learn steps til now= 552
# learn steps til now= 553
# learn steps til now= 554
# learn steps til now= 555
# learn steps til now= 556
# learn steps til now= 557
# learn steps til now= 558
# learn steps til now= 559
# learn steps til now= 560
# learn steps til now= 561
# learn steps til now= 562
# learn steps til now= 563
# learn steps til now= 564
# learn steps til now= 565
# learn steps til now= 566
# learn steps til now= 567
# learn steps til now= 568
# learn steps til now= 569
# learn steps til now= 570
# learn steps til now= 571
# learn steps til now= 572
# learn steps til now= 573
# learn steps til now= 574
# learn steps til now= 575
# learn steps til now= 576
# learn steps til now= 577
# learn steps til now= 578
# learn steps til now= 579
# learn steps til now= 580
# Episode 21, total steps= 3102
# learn steps til now= 581
# learn steps til now= 582
# learn steps til now= 583
# learn steps til now= 584
# learn steps til now= 585
# learn steps til now= 586
# learn steps til now= 587
# learn steps til now= 588
# Episode 22, total steps= 3144
# learn steps til now= 589
# learn steps til now= 590
# learn steps til now= 591
# learn steps til now= 592
# learn steps til now= 593
# learn steps til now= 594
# learn steps til now= 595
# learn steps til now= 596
# learn steps til now= 597
# learn steps til now= 598
# learn steps til now= 599
# learn steps til now= 600
# Episode 23, total steps= 3203
#
# learn steps=600: target_params_replaced
#
# learn steps til now= 601
# learn steps til now= 602
# learn steps til now= 603
# learn steps til now= 604
# learn steps til now= 605
# learn steps til now= 606
# learn steps til now= 607
# learn steps til now= 608
# learn steps til now= 609
# learn steps til now= 610
# learn steps til now= 611
# learn steps til now= 612
# learn steps til now= 613
# learn steps til now= 614
# learn steps til now= 615
# learn steps til now= 616
# learn steps til now= 617
# learn steps til now= 618
# learn steps til now= 619
# learn steps til now= 620
# learn steps til now= 621
# learn steps til now= 622
# learn steps til now= 623
# learn steps til now= 624
# learn steps til now= 625
# learn steps til now= 626
# learn steps til now= 627
# learn steps til now= 628
# learn steps til now= 629
# learn steps til now= 630
# learn steps til now= 631
# learn steps til now= 632
# learn steps til now= 633
# learn steps til now= 634
# learn steps til now= 635
# learn steps til now= 636
# learn steps til now= 637
# learn steps til now= 638
# learn steps til now= 639
# learn steps til now= 640
# learn steps til now= 641
# learn steps til now= 642
# learn steps til now= 643
# learn steps til now= 644
# learn steps til now= 645
# learn steps til now= 646
# learn steps til now= 647
# learn steps til now= 648
# learn steps til now= 649
# learn steps til now= 650
# learn steps til now= 651
# learn steps til now= 652
# learn steps til now= 653
# learn steps til now= 654
# learn steps til now= 655
# learn steps til now= 656
# learn steps til now= 657
# learn steps til now= 658
# learn steps til now= 659
# learn steps til now= 660
# learn steps til now= 661
# learn steps til now= 662
# learn steps til now= 663
# learn steps til now= 664
# learn steps til now= 665
# learn steps til now= 666
# learn steps til now= 667
# learn steps til now= 668
# learn steps til now= 669
# Episode 24, total steps= 3547
# learn steps til now= 670
# learn steps til now= 671
# learn steps til now= 672
# learn steps til now= 673
# learn steps til now= 674
# learn steps til now= 675
# learn steps til now= 676
# learn steps til now= 677
# learn steps til now= 678
# learn steps til now= 679
# learn steps til now= 680
# learn steps til now= 681
# learn steps til now= 682
# learn steps til now= 683
# learn steps til now= 684
# learn steps til now= 685
# learn steps til now= 686
# Episode 25, total steps= 3632
# learn steps til now= 687
# learn steps til now= 688
# learn steps til now= 689
# learn steps til now= 690
# learn steps til now= 691
# learn steps til now= 692
# learn steps til now= 693
# learn steps til now= 694
# Episode 26, total steps= 3673
# learn steps til now= 695
# learn steps til now= 696
# learn steps til now= 697
# learn steps til now= 698
# learn steps til now= 699
# learn steps til now= 700
# learn steps til now= 701
# learn steps til now= 702
# learn steps til now= 703
# learn steps til now= 704
# learn steps til now= 705
# learn steps til now= 706
# learn steps til now= 707
# learn steps til now= 708
# learn steps til now= 709
# learn steps til now= 710
# learn steps til now= 711
# learn steps til now= 712
# learn steps til now= 713
# learn steps til now= 714
# learn steps til now= 715
# learn steps til now= 716
# learn steps til now= 717
# learn steps til now= 718
# learn steps til now= 719
# learn steps til now= 720
# learn steps til now= 721
# learn steps til now= 722
# learn steps til now= 723
# learn steps til now= 724
# learn steps til now= 725
# learn steps til now= 726
# learn steps til now= 727
# learn steps til now= 728
# learn steps til now= 729
# learn steps til now= 730
# learn steps til now= 731
# learn steps til now= 732
# learn steps til now= 733
# learn steps til now= 734
# learn steps til now= 735
# learn steps til now= 736
# learn steps til now= 737
# learn steps til now= 738
# learn steps til now= 739
# learn steps til now= 740
# learn steps til now= 741
# learn steps til now= 742
# Episode 27, total steps= 3913
# learn steps til now= 743
# learn steps til now= 744
# learn steps til now= 745
# learn steps til now= 746
# learn steps til now= 747
# learn steps til now= 748
# learn steps til now= 749
# learn steps til now= 750
# learn steps til now= 751
# learn steps til now= 752
# learn steps til now= 753
# learn steps til now= 754
# learn steps til now= 755
# learn steps til now= 756
# learn steps til now= 757
# learn steps til now= 758
# learn steps til now= 759
# learn steps til now= 760
# learn steps til now= 761
# learn steps til now= 762
# learn steps til now= 763
# learn steps til now= 764
# learn steps til now= 765
# learn steps til now= 766
# learn steps til now= 767
# learn steps til now= 768
# learn steps til now= 769
# learn steps til now= 770
# learn steps til now= 771
# learn steps til now= 772
# learn steps til now= 773
# learn steps til now= 774
# learn steps til now= 775
# learn steps til now= 776
# learn steps til now= 777
# learn steps til now= 778
# learn steps til now= 779
# learn steps til now= 780
# learn steps til now= 781
# learn steps til now= 782
# learn steps til now= 783
# Episode 28, total steps= 4116
# learn steps til now= 784
# learn steps til now= 785
# learn steps til now= 786
# learn steps til now= 787
# learn steps til now= 788
# learn steps til now= 789
# learn steps til now= 790
# learn steps til now= 791
# learn steps til now= 792
# learn steps til now= 793
# learn steps til now= 794
# learn steps til now= 795
# learn steps til now= 796
# learn steps til now= 797
# learn steps til now= 798
# learn steps til now= 799
# learn steps til now= 800
#
# learn steps=800: target_params_replaced
#
# learn steps til now= 801
# learn steps til now= 802
# learn steps til now= 803
# learn steps til now= 804
# learn steps til now= 805
# learn steps til now= 806
# learn steps til now= 807
# learn steps til now= 808
# learn steps til now= 809
# learn steps til now= 810
# learn steps til now= 811
# learn steps til now= 812
# learn steps til now= 813
# learn steps til now= 814
# learn steps til now= 815
# learn steps til now= 816
# learn steps til now= 817
# Episode 29, total steps= 4288
# learn steps til now= 818
# learn steps til now= 819
# learn steps til now= 820
# learn steps til now= 821
# learn steps til now= 822
# learn steps til now= 823
# learn steps til now= 824
# learn steps til now= 825
# learn steps til now= 826
# learn steps til now= 827
# learn steps til now= 828
# learn steps til now= 829
# learn steps til now= 830
# learn steps til now= 831
# learn steps til now= 832
# learn steps til now= 833
# learn steps til now= 834
# learn steps til now= 835
# learn steps til now= 836
# learn steps til now= 837
# learn steps til now= 838
# learn steps til now= 839
# learn steps til now= 840
# learn steps til now= 841
# learn steps til now= 842
# learn steps til now= 843
# learn steps til now= 844
# learn steps til now= 845
# Episode 30, total steps= 4427
# learn steps til now= 846
# learn steps til now= 847
# learn steps til now= 848
# learn steps til now= 849
# learn steps til now= 850
# learn steps til now= 851
# learn steps til now= 852
# learn steps til now= 853
# learn steps til now= 854
# learn steps til now= 855
# learn steps til now= 856
# learn steps til now= 857
# learn steps til now= 858
# learn steps til now= 859
# learn steps til now= 860
# learn steps til now= 861
# learn steps til now= 862
# learn steps til now= 863
# learn steps til now= 864
# Episode 31, total steps= 4522
# learn steps til now= 865
# learn steps til now= 866
# learn steps til now= 867
# learn steps til now= 868
# learn steps til now= 869
# learn steps til now= 870
# learn steps til now= 871
# learn steps til now= 872
# learn steps til now= 873
# learn steps til now= 874
# learn steps til now= 875
# learn steps til now= 876
# learn steps til now= 877
# learn steps til now= 878
# learn steps til now= 879
# learn steps til now= 880
# learn steps til now= 881
# learn steps til now= 882
# learn steps til now= 883
# learn steps til now= 884
# learn steps til now= 885
# learn steps til now= 886
# learn steps til now= 887
# Episode 32, total steps= 4639
# learn steps til now= 888
# learn steps til now= 889
# learn steps til now= 890
# learn steps til now= 891
# learn steps til now= 892
# learn steps til now= 893
# learn steps til now= 894
# learn steps til now= 895
# learn steps til now= 896
# learn steps til now= 897
# learn steps til now= 898
# learn steps til now= 899
# learn steps til now= 900
# learn steps til now= 901
# learn steps til now= 902
# learn steps til now= 903
# learn steps til now= 904
# learn steps til now= 905
# learn steps til now= 906
# learn steps til now= 907
# learn steps til now= 908
# learn steps til now= 909
# learn steps til now= 910
# learn steps til now= 911
# learn steps til now= 912
# learn steps til now= 913
# learn steps til now= 914
# learn steps til now= 915
# learn steps til now= 916
# learn steps til now= 917
# learn steps til now= 918
# learn steps til now= 919
# learn steps til now= 920
# learn steps til now= 921
# learn steps til now= 922
# learn steps til now= 923
# learn steps til now= 924
# learn steps til now= 925
# learn steps til now= 926
# learn steps til now= 927
# learn steps til now= 928
# learn steps til now= 929
# learn steps til now= 930
# learn steps til now= 931
# learn steps til now= 932
# learn steps til now= 933
# learn steps til now= 934
# learn steps til now= 935
# learn steps til now= 936
# learn steps til now= 937
# learn steps til now= 938
# learn steps til now= 939
# learn steps til now= 940
# learn steps til now= 941
# learn steps til now= 942
# learn steps til now= 943
# learn steps til now= 944
# learn steps til now= 945
# learn steps til now= 946
# learn steps til now= 947
# learn steps til now= 948
# learn steps til now= 949
# learn steps til now= 950
# learn steps til now= 951
# learn steps til now= 952
# learn steps til now= 953
# learn steps til now= 954
# learn steps til now= 955
# learn steps til now= 956
# learn steps til now= 957
# learn steps til now= 958
# learn steps til now= 959
# learn steps til now= 960
# learn steps til now= 961
# learn steps til now= 962
# learn steps til now= 963
# learn steps til now= 964
# learn steps til now= 965
# learn steps til now= 966
# learn steps til now= 967
# learn steps til now= 968
# learn steps til now= 969
# learn steps til now= 970
# learn steps til now= 971
# learn steps til now= 972
# learn steps til now= 973
# learn steps til now= 974
# learn steps til now= 975
# learn steps til now= 976
# learn steps til now= 977
# learn steps til now= 978
# learn steps til now= 979
# learn steps til now= 980
# learn steps til now= 981
# learn steps til now= 982
# learn steps til now= 983
# learn steps til now= 984
# learn steps til now= 985
# learn steps til now= 986
# learn steps til now= 987
# learn steps til now= 988
# learn steps til now= 989
# learn steps til now= 990
# learn steps til now= 991
# learn steps til now= 992
# learn steps til now= 993
# learn steps til now= 994
# learn steps til now= 995
# learn steps til now= 996
# learn steps til now= 997
# learn steps til now= 998
# learn steps til now= 999
# learn steps til now= 1000
#
# learn steps=1000: target_params_replaced
#
# learn steps til now= 1001
# learn steps til now= 1002
# learn steps til now= 1003
# learn steps til now= 1004
# learn steps til now= 1005
# learn steps til now= 1006
# learn steps til now= 1007
# learn steps til now= 1008
# learn steps til now= 1009
# learn steps til now= 1010
# learn steps til now= 1011
# learn steps til now= 1012
# learn steps til now= 1013
# learn steps til now= 1014
# learn steps til now= 1015
# learn steps til now= 1016
# learn steps til now= 1017
# learn steps til now= 1018
# learn steps til now= 1019
# learn steps til now= 1020
# Episode 33, total steps= 5301
# learn steps til now= 1021
# learn steps til now= 1022
# learn steps til now= 1023
# Episode 34, total steps= 5319
# learn steps til now= 1024
# Episode 35, total steps= 5322
# learn steps til now= 1025
# Episode 36, total steps= 5329
# learn steps til now= 1026
# Episode 37, total steps= 5332
# Episode 38, total steps= 5335
# learn steps til now= 1027
# Episode 39, total steps= 5338
# learn steps til now= 1028
# Episode 40, total steps= 5345
# learn steps til now= 1029
# Episode 41, total steps= 5348
# learn steps til now= 1030
# learn steps til now= 1031
# learn steps til now= 1032
# learn steps til now= 1033
# Episode 42, total steps= 5369
# learn steps til now= 1034
# Episode 43, total steps= 5372
# learn steps til now= 1035
# Episode 44, total steps= 5376
# learn steps til now= 1036
# learn steps til now= 1037
# Episode 45, total steps= 5389
# learn steps til now= 1038
# learn steps til now= 1039
# learn steps til now= 1040
# Episode 46, total steps= 5401
# learn steps til now= 1041
# Episode 47, total steps= 5410
# learn steps til now= 1042
# learn steps til now= 1043
# learn steps til now= 1044
# learn steps til now= 1045
# Episode 48, total steps= 5429
# learn steps til now= 1046
# learn steps til now= 1047
# Episode 49, total steps= 5436
# learn steps til now= 1048
# learn steps til now= 1049
# learn steps til now= 1050
# Episode 50, total steps= 5455
# learn steps til now= 1051
# learn steps til now= 1052
# learn steps til now= 1053
# learn steps til now= 1054
# learn steps til now= 1055
# learn steps til now= 1056
# learn steps til now= 1057
# learn steps til now= 1058
# learn steps til now= 1059
# learn steps til now= 1060
# learn steps til now= 1061
# learn steps til now= 1062
# learn steps til now= 1063
# learn steps til now= 1064
# learn steps til now= 1065
# learn steps til now= 1066
# learn steps til now= 1067
# learn steps til now= 1068
# learn steps til now= 1069
# learn steps til now= 1070
# learn steps til now= 1071
# learn steps til now= 1072
# learn steps til now= 1073
# learn steps til now= 1074
# learn steps til now= 1075
# learn steps til now= 1076
# learn steps til now= 1077
# learn steps til now= 1078
# learn steps til now= 1079
# learn steps til now= 1080
# learn steps til now= 1081
# learn steps til now= 1082
# learn steps til now= 1083
# learn steps til now= 1084
# learn steps til now= 1085
# learn steps til now= 1086
# learn steps til now= 1087
# learn steps til now= 1088
# learn steps til now= 1089
# learn steps til now= 1090
# learn steps til now= 1091
# learn steps til now= 1092
# learn steps til now= 1093
# learn steps til now= 1094
# learn steps til now= 1095
# learn steps til now= 1096
# learn steps til now= 1097
# learn steps til now= 1098
# learn steps til now= 1099
# learn steps til now= 1100
# learn steps til now= 1101
# learn steps til now= 1102
# learn steps til now= 1103
# learn steps til now= 1104
# learn steps til now= 1105
# learn steps til now= 1106
# learn steps til now= 1107
# learn steps til now= 1108
# learn steps til now= 1109
# learn steps til now= 1110
# learn steps til now= 1111
# learn steps til now= 1112
# learn steps til now= 1113
# learn steps til now= 1114
# learn steps til now= 1115
# learn steps til now= 1116
# learn steps til now= 1117
# learn steps til now= 1118
# learn steps til now= 1119
# learn steps til now= 1120
# learn steps til now= 1121
# learn steps til now= 1122
# learn steps til now= 1123
# learn steps til now= 1124
# learn steps til now= 1125
# learn steps til now= 1126
# learn steps til now= 1127
# learn steps til now= 1128
# learn steps til now= 1129
# learn steps til now= 1130
# learn steps til now= 1131
# learn steps til now= 1132
# learn steps til now= 1133
# learn steps til now= 1134
# learn steps til now= 1135
# learn steps til now= 1136
# learn steps til now= 1137
# learn steps til now= 1138
# learn steps til now= 1139
# learn steps til now= 1140
# learn steps til now= 1141
# learn steps til now= 1142
# learn steps til now= 1143
# learn steps til now= 1144
# learn steps til now= 1145
# learn steps til now= 1146
# learn steps til now= 1147
# learn steps til now= 1148
# learn steps til now= 1149
# learn steps til now= 1150
# learn steps til now= 1151
# learn steps til now= 1152
# learn steps til now= 1153
# learn steps til now= 1154
# learn steps til now= 1155
# learn steps til now= 1156
# learn steps til now= 1157
# learn steps til now= 1158
# learn steps til now= 1159
# learn steps til now= 1160
# learn steps til now= 1161
# learn steps til now= 1162
# learn steps til now= 1163
# learn steps til now= 1164
# learn steps til now= 1165
# learn steps til now= 1166
# learn steps til now= 1167
# learn steps til now= 1168
# learn steps til now= 1169
# learn steps til now= 1170
# learn steps til now= 1171
# learn steps til now= 1172
# learn steps til now= 1173
# learn steps til now= 1174
# learn steps til now= 1175
# learn steps til now= 1176
# learn steps til now= 1177
# learn steps til now= 1178
# learn steps til now= 1179
# learn steps til now= 1180
# learn steps til now= 1181
# learn steps til now= 1182
# learn steps til now= 1183
# learn steps til now= 1184
# learn steps til now= 1185
# learn steps til now= 1186
# learn steps til now= 1187
# learn steps til now= 1188
# learn steps til now= 1189
# learn steps til now= 1190
# learn steps til now= 1191
# learn steps til now= 1192
# learn steps til now= 1193
# learn steps til now= 1194
# learn steps til now= 1195
# learn steps til now= 1196
# learn steps til now= 1197
# learn steps til now= 1198
# learn steps til now= 1199
# learn steps til now= 1200
#
# learn steps=1200: target_params_replaced
#
# learn steps til now= 1201
# learn steps til now= 1202
# learn steps til now= 1203
# learn steps til now= 1204
# learn steps til now= 1205
# learn steps til now= 1206
# learn steps til now= 1207
# learn steps til now= 1208
# learn steps til now= 1209
# learn steps til now= 1210
# learn steps til now= 1211
# learn steps til now= 1212
# learn steps til now= 1213
# learn steps til now= 1214
# learn steps til now= 1215
# learn steps til now= 1216
# learn steps til now= 1217
# learn steps til now= 1218
# learn steps til now= 1219
# learn steps til now= 1220
# learn steps til now= 1221
# learn steps til now= 1222
# learn steps til now= 1223
# learn steps til now= 1224
# learn steps til now= 1225
# learn steps til now= 1226
# learn steps til now= 1227
# learn steps til now= 1228
# learn steps til now= 1229
# learn steps til now= 1230
# learn steps til now= 1231
# learn steps til now= 1232
# learn steps til now= 1233
# learn steps til now= 1234
# learn steps til now= 1235
# learn steps til now= 1236
# learn steps til now= 1237
# learn steps til now= 1238
# learn steps til now= 1239
# learn steps til now= 1240
# learn steps til now= 1241
# learn steps til now= 1242
# learn steps til now= 1243
# Episode 51, total steps= 6419
# learn steps til now= 1244
# learn steps til now= 1245
# learn steps til now= 1246
# learn steps til now= 1247
# Episode 52, total steps= 6439
# learn steps til now= 1248
# learn steps til now= 1249
# learn steps til now= 1250
# learn steps til now= 1251
# learn steps til now= 1252
# learn steps til now= 1253
# learn steps til now= 1254
# learn steps til now= 1255
# learn steps til now= 1256
# learn steps til now= 1257
# learn steps til now= 1258
# learn steps til now= 1259
# learn steps til now= 1260
# learn steps til now= 1261
# learn steps til now= 1262
# learn steps til now= 1263
# learn steps til now= 1264
# learn steps til now= 1265
# Episode 53, total steps= 6529
# learn steps til now= 1266
# learn steps til now= 1267
# learn steps til now= 1268
# learn steps til now= 1269
# learn steps til now= 1270
# learn steps til now= 1271
# learn steps til now= 1272
# Episode 54, total steps= 6561
# learn steps til now= 1273
# learn steps til now= 1274
# learn steps til now= 1275
# learn steps til now= 1276
# learn steps til now= 1277
# learn steps til now= 1278
# learn steps til now= 1279
# learn steps til now= 1280
# learn steps til now= 1281
# learn steps til now= 1282
# learn steps til now= 1283
# learn steps til now= 1284
# learn steps til now= 1285
# learn steps til now= 1286
# Episode 55, total steps= 6633
# learn steps til now= 1287
# learn steps til now= 1288
# learn steps til now= 1289
# learn steps til now= 1290
# learn steps til now= 1291
# learn steps til now= 1292
# learn steps til now= 1293
# learn steps til now= 1294
# learn steps til now= 1295
# learn steps til now= 1296
# learn steps til now= 1297
# learn steps til now= 1298
# learn steps til now= 1299
# learn steps til now= 1300
# learn steps til now= 1301
# learn steps til now= 1302
# learn steps til now= 1303
# learn steps til now= 1304
# learn steps til now= 1305
# learn steps til now= 1306
# learn steps til now= 1307
# learn steps til now= 1308
# learn steps til now= 1309
# learn steps til now= 1310
# learn steps til now= 1311
# Episode 56, total steps= 6760
# learn steps til now= 1312
# learn steps til now= 1313
# Episode 57, total steps= 6769
# learn steps til now= 1314
# learn steps til now= 1315
# learn steps til now= 1316
# learn steps til now= 1317
# learn steps til now= 1318
# learn steps til now= 1319
# learn steps til now= 1320
# learn steps til now= 1321
# learn steps til now= 1322
# learn steps til now= 1323
# Episode 58, total steps= 6817
# learn steps til now= 1324
# learn steps til now= 1325
# learn steps til now= 1326
# learn steps til now= 1327
# learn steps til now= 1328
# learn steps til now= 1329
# learn steps til now= 1330
# learn steps til now= 1331
# learn steps til now= 1332
# learn steps til now= 1333
# learn steps til now= 1334
# learn steps til now= 1335
# learn steps til now= 1336
# learn steps til now= 1337
# Episode 59, total steps= 6887
# learn steps til now= 1338
# learn steps til now= 1339
# learn steps til now= 1340
# learn steps til now= 1341
# learn steps til now= 1342
# learn steps til now= 1343
# learn steps til now= 1344
# learn steps til now= 1345
# learn steps til now= 1346
# learn steps til now= 1347
# learn steps til now= 1348
# learn steps til now= 1349
# learn steps til now= 1350
# learn steps til now= 1351
# Episode 60, total steps= 6959
# learn steps til now= 1352
# learn steps til now= 1353
# learn steps til now= 1354
# learn steps til now= 1355
# learn steps til now= 1356
# learn steps til now= 1357
# learn steps til now= 1358
# learn steps til now= 1359
# learn steps til now= 1360
# learn steps til now= 1361
# learn steps til now= 1362
# learn steps til now= 1363
# learn steps til now= 1364
# Episode 61, total steps= 7021
# learn steps til now= 1365
# Episode 62, total steps= 7027
# learn steps til now= 1366
# learn steps til now= 1367
# learn steps til now= 1368
# learn steps til now= 1369
# learn steps til now= 1370
# learn steps til now= 1371
# learn steps til now= 1372
# learn steps til now= 1373
# Episode 63, total steps= 7069
# learn steps til now= 1374
# learn steps til now= 1375
# learn steps til now= 1376
# learn steps til now= 1377
# learn steps til now= 1378
# learn steps til now= 1379
# learn steps til now= 1380
# learn steps til now= 1381
# learn steps til now= 1382
# learn steps til now= 1383
# learn steps til now= 1384
# learn steps til now= 1385
# learn steps til now= 1386
# learn steps til now= 1387
# learn steps til now= 1388
# learn steps til now= 1389
# learn steps til now= 1390
# learn steps til now= 1391
# learn steps til now= 1392
# learn steps til now= 1393
# learn steps til now= 1394
# learn steps til now= 1395
# learn steps til now= 1396
# learn steps til now= 1397
# learn steps til now= 1398
# learn steps til now= 1399
# learn steps til now= 1400
#
# learn steps=1400: target_params_replaced
#
# learn steps til now= 1401
# learn steps til now= 1402
# learn steps til now= 1403
# learn steps til now= 1404
# learn steps til now= 1405
# Episode 64, total steps= 7229
# learn steps til now= 1406
# learn steps til now= 1407
# learn steps til now= 1408
# learn steps til now= 1409
# learn steps til now= 1410
# learn steps til now= 1411
# learn steps til now= 1412
# learn steps til now= 1413
# learn steps til now= 1414
# learn steps til now= 1415
# learn steps til now= 1416
# learn steps til now= 1417
# learn steps til now= 1418
# learn steps til now= 1419
# learn steps til now= 1420
# learn steps til now= 1421
# learn steps til now= 1422
# learn steps til now= 1423
# learn steps til now= 1424
# learn steps til now= 1425
# learn steps til now= 1426
# learn steps til now= 1427
# learn steps til now= 1428
# learn steps til now= 1429
# learn steps til now= 1430
# learn steps til now= 1431
# learn steps til now= 1432
# learn steps til now= 1433
# learn steps til now= 1434
# learn steps til now= 1435
# learn steps til now= 1436
# learn steps til now= 1437
# learn steps til now= 1438
# Episode 65, total steps= 7392
# learn steps til now= 1439
# learn steps til now= 1440
# learn steps til now= 1441
# learn steps til now= 1442
# learn steps til now= 1443
# learn steps til now= 1444
# learn steps til now= 1445
# learn steps til now= 1446
# learn steps til now= 1447
# learn steps til now= 1448
# learn steps til now= 1449
# learn steps til now= 1450
# learn steps til now= 1451
# learn steps til now= 1452
# Episode 66, total steps= 7463
# learn steps til now= 1453
# learn steps til now= 1454
# learn steps til now= 1455
# learn steps til now= 1456
# learn steps til now= 1457
# learn steps til now= 1458
# learn steps til now= 1459
# learn steps til now= 1460
# learn steps til now= 1461
# Episode 67, total steps= 7509
# learn steps til now= 1462
# learn steps til now= 1463
# learn steps til now= 1464
# learn steps til now= 1465
# learn steps til now= 1466
# learn steps til now= 1467
# learn steps til now= 1468
# learn steps til now= 1469
# learn steps til now= 1470
# learn steps til now= 1471
# learn steps til now= 1472
# learn steps til now= 1473
# learn steps til now= 1474
# Episode 68, total steps= 7571
# learn steps til now= 1475
# Episode 69, total steps= 7577
# learn steps til now= 1476
# learn steps til now= 1477
# learn steps til now= 1478
# learn steps til now= 1479
# learn steps til now= 1480
# learn steps til now= 1481
# learn steps til now= 1482
# learn steps til now= 1483
# learn steps til now= 1484
# Episode 70, total steps= 7622
# learn steps til now= 1485
# learn steps til now= 1486
# learn steps til now= 1487
# learn steps til now= 1488
# learn steps til now= 1489
# learn steps til now= 1490
# learn steps til now= 1491
# learn steps til now= 1492
# Episode 71, total steps= 7663
# learn steps til now= 1493
# learn steps til now= 1494
# Episode 72, total steps= 7673
# learn steps til now= 1495
# learn steps til now= 1496
# learn steps til now= 1497
# learn steps til now= 1498
# learn steps til now= 1499
# learn steps til now= 1500
# learn steps til now= 1501
# learn steps til now= 1502
# learn steps til now= 1503
# learn steps til now= 1504
# learn steps til now= 1505
# learn steps til now= 1506
# learn steps til now= 1507
# learn steps til now= 1508
# learn steps til now= 1509
# Episode 73, total steps= 7749
# learn steps til now= 1510
# learn steps til now= 1511
# learn steps til now= 1512
# learn steps til now= 1513
# learn steps til now= 1514
# learn steps til now= 1515
# Episode 74, total steps= 7777
# learn steps til now= 1516
# learn steps til now= 1517
# learn steps til now= 1518
# learn steps til now= 1519
# Episode 75, total steps= 7796
# learn steps til now= 1520
# Episode 76, total steps= 7805
# learn steps til now= 1521
# learn steps til now= 1522
# learn steps til now= 1523
# learn steps til now= 1524
# learn steps til now= 1525
# learn steps til now= 1526
# learn steps til now= 1527
# learn steps til now= 1528
# learn steps til now= 1529
# learn steps til now= 1530
# learn steps til now= 1531
# learn steps til now= 1532
# learn steps til now= 1533
# learn steps til now= 1534
# learn steps til now= 1535
# learn steps til now= 1536
# learn steps til now= 1537
# learn steps til now= 1538
# learn steps til now= 1539
# learn steps til now= 1540
# learn steps til now= 1541
# learn steps til now= 1542
# learn steps til now= 1543
# learn steps til now= 1544
# learn steps til now= 1545
# learn steps til now= 1546
# learn steps til now= 1547
# learn steps til now= 1548
# learn steps til now= 1549
# learn steps til now= 1550
# Episode 77, total steps= 7952
# learn steps til now= 1551
# learn steps til now= 1552
# learn steps til now= 1553
# learn steps til now= 1554
# learn steps til now= 1555
# learn steps til now= 1556
# learn steps til now= 1557
# learn steps til now= 1558
# learn steps til now= 1559
# learn steps til now= 1560
# learn steps til now= 1561
# learn steps til now= 1562
# learn steps til now= 1563
# learn steps til now= 1564
# learn steps til now= 1565
# learn steps til now= 1566
# Episode 78, total steps= 8034
# learn steps til now= 1567
# learn steps til now= 1568
# learn steps til now= 1569
# learn steps til now= 1570
# learn steps til now= 1571
# learn steps til now= 1572
# learn steps til now= 1573
# learn steps til now= 1574
# learn steps til now= 1575
# learn steps til now= 1576
# learn steps til now= 1577
# Episode 79, total steps= 8086
# learn steps til now= 1578
# learn steps til now= 1579
# Episode 80, total steps= 8100
# learn steps til now= 1580
# learn steps til now= 1581
# Episode 81, total steps= 8107
# learn steps til now= 1582
# learn steps til now= 1583
# learn steps til now= 1584
# learn steps til now= 1585
# learn steps til now= 1586
# learn steps til now= 1587
# learn steps til now= 1588
# learn steps til now= 1589
# learn steps til now= 1590
# learn steps til now= 1591
# learn steps til now= 1592
# learn steps til now= 1593
# learn steps til now= 1594
# learn steps til now= 1595
# learn steps til now= 1596
# learn steps til now= 1597
# learn steps til now= 1598
# learn steps til now= 1599
# learn steps til now= 1600
#
# learn steps=1600: target_params_replaced
#
# learn steps til now= 1601
# learn steps til now= 1602
# learn steps til now= 1603
# learn steps til now= 1604
# learn steps til now= 1605
# learn steps til now= 1606
# learn steps til now= 1607
# learn steps til now= 1608
# learn steps til now= 1609
# Episode 82, total steps= 8248
# learn steps til now= 1610
# Episode 83, total steps= 8255
# learn steps til now= 1611
# learn steps til now= 1612
# learn steps til now= 1613
# learn steps til now= 1614
# learn steps til now= 1615
# Episode 84, total steps= 8279
# learn steps til now= 1616
# learn steps til now= 1617
# learn steps til now= 1618
# learn steps til now= 1619
# learn steps til now= 1620
# learn steps til now= 1621
# learn steps til now= 1622
# learn steps til now= 1623
# learn steps til now= 1624
# learn steps til now= 1625
# learn steps til now= 1626
# learn steps til now= 1627
# learn steps til now= 1628
# learn steps til now= 1629
# learn steps til now= 1630
# learn steps til now= 1631
# learn steps til now= 1632
# learn steps til now= 1633
# learn steps til now= 1634
# learn steps til now= 1635
# learn steps til now= 1636
# learn steps til now= 1637
# learn steps til now= 1638
# learn steps til now= 1639
# learn steps til now= 1640
# learn steps til now= 1641
# learn steps til now= 1642
# learn steps til now= 1643
# learn steps til now= 1644
# learn steps til now= 1645
# learn steps til now= 1646
# learn steps til now= 1647
# Episode 85, total steps= 8438
# learn steps til now= 1648
# learn steps til now= 1649
# learn steps til now= 1650
# Episode 86, total steps= 8452
# learn steps til now= 1651
# learn steps til now= 1652
# learn steps til now= 1653
# learn steps til now= 1654
# Episode 87, total steps= 8474
# learn steps til now= 1655
# learn steps til now= 1656
# learn steps til now= 1657
# learn steps til now= 1658
# learn steps til now= 1659
# learn steps til now= 1660
# learn steps til now= 1661
# Episode 88, total steps= 8507
# learn steps til now= 1662
# learn steps til now= 1663
# Episode 89, total steps= 8519
# learn steps til now= 1664
# learn steps til now= 1665
# learn steps til now= 1666
# learn steps til now= 1667
# learn steps til now= 1668
# learn steps til now= 1669
# learn steps til now= 1670
# learn steps til now= 1671
# learn steps til now= 1672
# learn steps til now= 1673
# learn steps til now= 1674
# learn steps til now= 1675
# learn steps til now= 1676
# learn steps til now= 1677
# Episode 90, total steps= 8588
# learn steps til now= 1678
# Episode 91, total steps= 8595
# learn steps til now= 1679
# learn steps til now= 1680
# Episode 92, total steps= 8601
# learn steps til now= 1681
# Episode 93, total steps= 8609
# learn steps til now= 1682
# learn steps til now= 1683
# learn steps til now= 1684
# Episode 94, total steps= 8621
# learn steps til now= 1685
# learn steps til now= 1686
# Episode 95, total steps= 8632
# learn steps til now= 1687
# learn steps til now= 1688
# learn steps til now= 1689
# Episode 96, total steps= 8648
# learn steps til now= 1690
# Episode 97, total steps= 8654
# learn steps til now= 1691
# Episode 98, total steps= 8660
# learn steps til now= 1692
# learn steps til now= 1693
# Episode 99, total steps= 8670
# learn steps til now= 1694
# learn steps til now= 1695
# Episode 100, total steps= 8676
# learn steps til now= 1696
# Episode 101, total steps= 8682
# learn steps til now= 1697
# Episode 102, total steps= 8690
# learn steps til now= 1698
# learn steps til now= 1699
# Episode 103, total steps= 8696
# learn steps til now= 1700
# learn steps til now= 1701
# Episode 104, total steps= 8708
# learn steps til now= 1702
# learn steps til now= 1703
# Episode 105, total steps= 8720
# learn steps til now= 1704
# learn steps til now= 1705
# Episode 106, total steps= 8726
# learn steps til now= 1706
# Episode 107, total steps= 8732
# learn steps til now= 1707
# Episode 108, total steps= 8738
# learn steps til now= 1708
# Episode 109, total steps= 8744
# learn steps til now= 1709
# learn steps til now= 1710
# Episode 110, total steps= 8751
# learn steps til now= 1711
# Episode 111, total steps= 8757
# ...
# learn steps til now= 1865
# learn steps til now= 1866
# Episode 205, total steps= 9534
# learn steps til now= 1867
# learn steps til now= 1868
# Episode 206, total steps= 9544
# learn steps til now= 1869
# learn steps til now= 1870
# learn steps til now= 1871
# Episode 207, total steps= 9557
# learn steps til now= 1872
# Episode 208, total steps= 9563
# learn steps til now= 1873
# learn steps til now= 1874
# Episode 209, total steps= 9572
# learn steps til now= 1875
# learn steps til now= 1876
# Episode 210, total steps= 9582
# learn steps til now= 1877
# Episode 211, total steps= 9589
# learn steps til now= 1878
# learn steps til now= 1879
# Episode 212, total steps= 9597
# learn steps til now= 1880
# learn steps til now= 1881
# Episode 213, total steps= 9607
# learn steps til now= 1882
# Episode 214, total steps= 9613
# learn steps til now= 1883
# Episode 215, total steps= 9619
# learn steps til now= 1884
# learn steps til now= 1885
# Episode 216, total steps= 9629
# learn steps til now= 1886
# learn steps til now= 1887
# Episode 217, total steps= 9640
# learn steps til now= 1888
# learn steps til now= 1889
# Episode 218, total steps= 9648
# learn steps til now= 1890
# learn steps til now= 1891
# Episode 219, total steps= 9658
# learn steps til now= 1892
# Episode 220, total steps= 9665
# learn steps til now= 1893
# learn steps til now= 1894
# Episode 221, total steps= 9671
# learn steps til now= 1895
# Episode 222, total steps= 9677
# learn steps til now= 1896
# Episode 223, total steps= 9683
# learn steps til now= 1897
# learn steps til now= 1898
# Episode 224, total steps= 9692
# learn steps til now= 1899
# Episode 225, total steps= 9698
# learn steps til now= 1900
# Episode 226, total steps= 9704
# learn steps til now= 1901
# learn steps til now= 1902
# Episode 227, total steps= 9714
# learn steps til now= 1903
# Episode 228, total steps= 9720
# learn steps til now= 1904
# learn steps til now= 1905
# Episode 229, total steps= 9726
# learn steps til now= 1906
# Episode 230, total steps= 9734
# learn steps til now= 1907
# learn steps til now= 1908
# Episode 231, total steps= 9742
# learn steps til now= 1909
# Episode 232, total steps= 9749
# learn steps til now= 1910
# learn steps til now= 1911
# Episode 233, total steps= 9757
# learn steps til now= 1912
# Episode 234, total steps= 9764
# learn steps til now= 1913
# Episode 235, total steps= 9770
# learn steps til now= 1914
# learn steps til now= 1915
# Episode 236, total steps= 9777
# learn steps til now= 1916
# Episode 237, total steps= 9783
# learn steps til now= 1917
# learn steps til now= 1918
# Episode 238, total steps= 9791
# learn steps til now= 1919
# Episode 239, total steps= 9797
# learn steps til now= 1920
# learn steps til now= 1921
# Episode 240, total steps= 9806
# learn steps til now= 1922
# learn steps til now= 1923
# Episode 241, total steps= 9817
# learn steps til now= 1924
# Episode 242, total steps= 9823
# learn steps til now= 1925
# Episode 243, total steps= 9829
# learn steps til now= 1926
# learn steps til now= 1927
# Episode 244, total steps= 9837
# learn steps til now= 1928
# learn steps til now= 1929
# Episode 245, total steps= 9848
# learn steps til now= 1930
# Episode 246, total steps= 9855
# learn steps til now= 1931
# learn steps til now= 1932
# Episode 247, total steps= 9862
# learn steps til now= 1933
# Episode 248, total steps= 9868
# learn steps til now= 1934
# learn steps til now= 1935
# Episode 249, total steps= 9879
# learn steps til now= 1936
# learn steps til now= 1937
# Episode 250, total steps= 9887
# learn steps til now= 1938
# learn steps til now= 1939
# Episode 251, total steps= 9897
# learn steps til now= 1940
# learn steps til now= 1941
# Episode 252, total steps= 9907
# learn steps til now= 1942
# Episode 253, total steps= 9915
# learn steps til now= 1943
# learn steps til now= 1944
# learn steps til now= 1945
# Episode 254, total steps= 9929
# learn steps til now= 1946
# learn steps til now= 1947
# Episode 255, total steps= 9939
# learn steps til now= 1948
# Episode 256, total steps= 9945
# learn steps til now= 1949
# learn steps til now= 1950
# Episode 257, total steps= 9952
# learn steps til now= 1951
# Episode 258, total steps= 9960
# learn steps til now= 1952
# learn steps til now= 1953
# Episode 259, total steps= 9969
# learn steps til now= 1954
# Episode 260, total steps= 9975
# learn steps til now= 1955
# learn steps til now= 1956
# Episode 261, total steps= 9982
# learn steps til now= 1957
# Episode 262, total steps= 9988
# learn steps til now= 1958
# Episode 263, total steps= 9995
# learn steps til now= 1959
# learn steps til now= 1960
# Episode 264, total steps= 10001
# learn steps til now= 1961
# Episode 265, total steps= 10009
# learn steps til now= 1962
# learn steps til now= 1963
# Episode 266, total steps= 10017
# learn steps til now= 1964
# Episode 267, total steps= 10023
# learn steps til now= 1965
# learn steps til now= 1966
# Episode 268, total steps= 10034
# learn steps til now= 1967
# Episode 269, total steps= 10040
# learn steps til now= 1968
# learn steps til now= 1969
# Episode 270, total steps= 10046
# learn steps til now= 1970
# Episode 271, total steps= 10054
# learn steps til now= 1971
# learn steps til now= 1972
# Episode 272, total steps= 10064
# learn steps til now= 1973
# Episode 273, total steps= 10070
# learn steps til now= 1974
# learn steps til now= 1975
# Episode 274, total steps= 10076
# learn steps til now= 1976
# Episode 275, total steps= 10082
# learn steps til now= 1977
# learn steps til now= 1978
# Episode 276, total steps= 10094
# learn steps til now= 1979
# learn steps til now= 1980
# Episode 277, total steps= 10102
# learn steps til now= 1981
# Episode 278, total steps= 10110
# learn steps til now= 1982
# learn steps til now= 1983
# Episode 279, total steps= 10116
# Episode 280, total steps= 10120
# learn steps til now= 1984
# learn steps til now= 1985
# Episode 281, total steps= 10126
# learn steps til now= 1986
# Episode 282, total steps= 10132
# learn steps til now= 1987
# Episode 283, total steps= 10138
# learn steps til now= 1988
# learn steps til now= 1989
# Episode 284, total steps= 10149
# learn steps til now= 1990
# learn steps til now= 1991
# Episode 285, total steps= 10159
# learn steps til now= 1992
# Episode 286, total steps= 10165
# learn steps til now= 1993
# learn steps til now= 1994
# Episode 287, total steps= 10171
# learn steps til now= 1995
# learn steps til now= 1996
# Episode 288, total steps= 10182
# learn steps til now= 1997
# learn steps til now= 1998
# Episode 289, total steps= 10192
# learn steps til now= 1999
# Episode 290, total steps= 10199
# learn steps til now= 2000
#
# learn steps=2000: target_params_replaced
#
# learn steps til now= 2001
# Episode 291, total steps= 10206
# learn steps til now= 2002
# Episode 292, total steps= 10214
# learn steps til now= 2003
# learn steps til now= 2004
# learn steps til now= 2005
# learn steps til now= 2006
# learn steps til now= 2007
# learn steps til now= 2008
# learn steps til now= 2009
# learn steps til now= 2010
# learn steps til now= 2011
# Episode 293, total steps= 10259
# learn steps til now= 2012
# Episode 294, total steps= 10264
# learn steps til now= 2013
# learn steps til now= 2014
# learn steps til now= 2015
# learn steps til now= 2016
# learn steps til now= 2017
# learn steps til now= 2018
# Episode 295, total steps= 10293
# learn steps til now= 2019
# learn steps til now= 2020
# learn steps til now= 2021
# Episode 296, total steps= 10307
# learn steps til now= 2022
# Episode 297, total steps= 10312
# learn steps til now= 2023
# learn steps til now= 2024
# learn steps til now= 2025
# Episode 298, total steps= 10328
# learn steps til now= 2026
# Episode 299, total steps= 10335
# learn steps til now= 2027
# learn steps til now= 2028
# learn steps til now= 2029
# Episode 300, total steps= 10346
# learn steps til now= 2030
# learn steps til now= 2031
# Episode 301, total steps= 10356
# learn steps til now= 2032
# Episode 302, total steps= 10361
# learn steps til now= 2033
# learn steps til now= 2034
# learn steps til now= 2035
# learn steps til now= 2036
# Episode 303, total steps= 10385
# learn steps til now= 2037
# Episode 304, total steps= 10390
# learn steps til now= 2038
# Episode 305, total steps= 10394
# learn steps til now= 2039
# Episode 306, total steps= 10398
# learn steps til now= 2040
# Episode 307, total steps= 10405
# learn steps til now= 2041
# Episode 308, total steps= 10409
# learn steps til now= 2042
# Episode 309, total steps= 10415
# learn steps til now= 2043
# Episode 310, total steps= 10419
# learn steps til now= 2044
# Episode 311, total steps= 10425
# learn steps til now= 2045
# Episode 312, total steps= 10429
# learn steps til now= 2046
# learn steps til now= 2047
# Episode 313, total steps= 10440
# learn steps til now= 2048
# Episode 314, total steps= 10445
# learn steps til now= 2049
# Episode 315, total steps= 10448
# learn steps til now= 2050
# Episode 316, total steps= 10454
# learn steps til now= 2051
# learn steps til now= 2052
# Episode 317, total steps= 10464
# learn steps til now= 2053
# learn steps til now= 2054
# Episode 318, total steps= 10475
# learn steps til now= 2055
# Episode 319, total steps= 10479
# learn steps til now= 2056
# Episode 320, total steps= 10485
# learn steps til now= 2057
# learn steps til now= 2058
# Episode 321, total steps= 10491
# learn steps til now= 2059
# Episode 322, total steps= 10496
# learn steps til now= 2060
# Episode 323, total steps= 10501
# learn steps til now= 2061
# learn steps til now= 2062
# learn steps til now= 2063
# learn steps til now= 2064
# Episode 324, total steps= 10522
# learn steps til now= 2065
# Episode 325, total steps= 10530
# learn steps til now= 2066
# Episode 326, total steps= 10534
# learn steps til now= 2067
# learn steps til now= 2068
# Episode 327, total steps= 10542
# learn steps til now= 2069
# Episode 328, total steps= 10550
# learn steps til now= 2070
# Episode 329, total steps= 10555
# learn steps til now= 2071
# learn steps til now= 2072
# learn steps til now= 2073
# Episode 330, total steps= 10566
# learn steps til now= 2074
# Episode 331, total steps= 10572
# learn steps til now= 2075
# learn steps til now= 2076
# learn steps til now= 2077
# Episode 332, total steps= 10590
# learn steps til now= 2078
# Episode 333, total steps= 10594
# learn steps til now= 2079
# learn steps til now= 2080
# learn steps til now= 2081
# learn steps til now= 2082
# learn steps til now= 2083
# Episode 334, total steps= 10619
# learn steps til now= 2084
# Episode 335, total steps= 10623
# learn steps til now= 2085
# Episode 336, total steps= 10626
# Episode 337, total steps= 10630
# learn steps til now= 2086
# Episode 338, total steps= 10635
# learn steps til now= 2087
# learn steps til now= 2088
# learn steps til now= 2089
# Episode 339, total steps= 10648
# learn steps til now= 2090
# Episode 340, total steps= 10652
# learn steps til now= 2091
# learn steps til now= 2092
# Episode 341, total steps= 10662
# learn steps til now= 2093
# Episode 342, total steps= 10670
# learn steps til now= 2094
# learn steps til now= 2095
# Episode 343, total steps= 10680
# learn steps til now= 2096
# learn steps til now= 2097
# Episode 344, total steps= 10688
# learn steps til now= 2098
# learn steps til now= 2099
# learn steps til now= 2100
# learn steps til now= 2101
# Episode 345, total steps= 10706
# Episode 346, total steps= 10710
# learn steps til now= 2102
# Episode 347, total steps= 10714
# learn steps til now= 2103
# Episode 348, total steps= 10720
# learn steps til now= 2104
# learn steps til now= 2105
# Episode 349, total steps= 10726
# Episode 350, total steps= 10730
# learn steps til now= 2106
# Episode 351, total steps= 10734
# learn steps til now= 2107
# learn steps til now= 2108
# learn steps til now= 2109
# Episode 352, total steps= 10747
# learn steps til now= 2110
# Episode 353, total steps= 10755
# learn steps til now= 2111
# Episode 354, total steps= 10759
# learn steps til now= 2112
# Episode 355, total steps= 10765
# learn steps til now= 2113
# Episode 356, total steps= 10769
# learn steps til now= 2114
# Episode 357, total steps= 10773
# learn steps til now= 2115
# Episode 358, total steps= 10780
# learn steps til now= 2116
# Episode 359, total steps= 10784
# learn steps til now= 2117
# Episode 360, total steps= 10790
# learn steps til now= 2118
# Episode 361, total steps= 10794
# learn steps til now= 2119
# Episode 362, total steps= 10798
# learn steps til now= 2120
# learn steps til now= 2121
# Episode 363, total steps= 10807
# learn steps til now= 2122
# learn steps til now= 2123
# Episode 364, total steps= 10817
# learn steps til now= 2124
# Episode 365, total steps= 10825
# learn steps til now= 2125
# learn steps til now= 2126
# Episode 366, total steps= 10831
# learn steps til now= 2127
# Episode 367, total steps= 10837
# learn steps til now= 2128
# learn steps til now= 2129
# Episode 368, total steps= 10850
# learn steps til now= 2130
# learn steps til now= 2131
# Episode 369, total steps= 10860
# learn steps til now= 2132
# learn steps til now= 2133
# Episode 370, total steps= 10866
# learn steps til now= 2134
# learn steps til now= 2135
# learn steps til now= 2136
# Episode 371, total steps= 10882
# learn steps til now= 2137
# Episode 372, total steps= 10889
# learn steps til now= 2138
# Episode 373, total steps= 10893
# learn steps til now= 2139
# Episode 374, total steps= 10897
# learn steps til now= 2140
# learn steps til now= 2141
# Episode 375, total steps= 10907
# learn steps til now= 2142
# learn steps til now= 2143
# Episode 376, total steps= 10920
# learn steps til now= 2144
# Episode 377, total steps= 10924
# learn steps til now= 2145
# learn steps til now= 2146
# learn steps til now= 2147
# Episode 378, total steps= 10938
# learn steps til now= 2148
# learn steps til now= 2149
# learn steps til now= 2150
# learn steps til now= 2151
# learn steps til now= 2152
# learn steps til now= 2153
# Episode 379, total steps= 10966
# learn steps til now= 2154
# Episode 380, total steps= 10975
# learn steps til now= 2155
# Episode 381, total steps= 10979
# learn steps til now= 2156
# learn steps til now= 2157
# Episode 382, total steps= 10988
# learn steps til now= 2158
# Episode 383, total steps= 10995
# learn steps til now= 2159
# learn steps til now= 2160
# learn steps til now= 2161
# Episode 384, total steps= 11006
# learn steps til now= 2162
# Episode 385, total steps= 11015
# learn steps til now= 2163
# Episode 386, total steps= 11020
# learn steps til now= 2164
# Episode 387, total steps= 11025
# learn steps til now= 2165
# Episode 388, total steps= 11029
# learn steps til now= 2166
# learn steps til now= 2167
# Episode 389, total steps= 11036
# learn steps til now= 2168
# learn steps til now= 2169
# Episode 390, total steps= 11050
# learn steps til now= 2170
# Episode 391, total steps= 11055
# learn steps til now= 2171
# Episode 392, total steps= 11060
# learn steps til now= 2172
# Episode 393, total steps= 11064
# learn steps til now= 2173
# learn steps til now= 2174
# Episode 394, total steps= 11072
# learn steps til now= 2175
# Episode 395, total steps= 11080
# learn steps til now= 2176
# Episode 396, total steps= 11084
# learn steps til now= 2177
# learn steps til now= 2178
# learn steps til now= 2179
# learn steps til now= 2180
# Episode 397, total steps= 11105
# learn steps til now= 2181
# Episode 398, total steps= 11109
# learn steps til now= 2182
# Episode 399, total steps= 11113
# learn steps til now= 2183
# learn steps til now= 2184
# Episode 400, total steps= 11123
# learn steps til now= 2185
# Episode 401, total steps= 11130
# learn steps til now= 2186
# Episode 402, total steps= 11134
# learn steps til now= 2187
# learn steps til now= 2188
# Episode 403, total steps= 11141
# learn steps til now= 2189
# Episode 404, total steps= 11150
# learn steps til now= 2190
# Episode 405, total steps= 11154
# learn steps til now= 2191
# Episode 406, total steps= 11157
# learn steps til now= 2192
# Episode 407, total steps= 11165
# learn steps til now= 2193
# Episode 408, total steps= 11170
# learn steps til now= 2194
# learn steps til now= 2195
# Episode 409, total steps= 11179
# learn steps til now= 2196
# Episode 410, total steps= 11183
# learn steps til now= 2197
# learn steps til now= 2198
# Episode 411, total steps= 11193
# learn steps til now= 2199
# learn steps til now= 2200
# Episode 412, total steps= 11203
#
# learn steps=2200: target_params_replaced
#
# learn steps til now= 2201
# learn steps til now= 2202
# learn steps til now= 2203
# Episode 413, total steps= 11216
# learn steps til now= 2204
# Episode 414, total steps= 11221
# Cannot execute code, session has been disposed. Please try restarting the Kernel.
# The Kernel crashed while executing code in the the current cell or a previous cell. Please review the code in the cell(s) to identify a possible cause of the failure. Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info. View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
